# %% [markdown]
# <a href="https://colab.research.google.com/github/PuttaShivani/Cognifyz_technologies_intern/blob/main/Task1_Predict_Restaurant_Ratings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as panda
import numpy as npy

# %%
restaurant_dataset = panda.read_csv('/content/Dataset .csv')

# %%
restaurant_dataset
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
restaurant_dataset = restaurant_dataset.drop('Restaurant ID', axis=1)
restaurant_dataset = restaurant_dataset.drop('Restaurant Name', axis=1)
restaurant_dataset = restaurant_dataset.drop('Country Code', axis=1)
restaurant_dataset = restaurant_dataset.drop('City', axis=1)
restaurant_dataset = restaurant_dataset.drop('Address', axis=1)
restaurant_dataset = restaurant_dataset.drop('Locality', axis=1)
restaurant_dataset = restaurant_dataset.drop('Locality Verbose', axis=1)
restaurant_dataset = restaurant_dataset.drop('Longitude', axis=1)
restaurant_dataset = restaurant_dataset.drop('Latitude', axis=1)
restaurant_dataset = restaurant_dataset.drop('Cuisines', axis=1)
restaurant_dataset = restaurant_dataset.drop('Currency', axis=1)

# %%
restaurant_dataset.shape
# Out:
# (9551, 10)

# %%
restaurant_dataset.info
# Out:
# <bound method DataFrame.info of       Average Cost for two Has Table booking Has Online delivery  \
# 0                     1100               Yes                  No
# 1                     1200               Yes                  No
# 2                     4000               Yes                  No
# 3                     1500                No                  No
# 4                     1500               Yes                  No
# ...                    ...               ...                 ...
# 9546                    80                No                  No
# 9547                   105                No                  No
# 9548                   170                No                  No
# 9549                   120                No                  No
# 9550                    55                No                  No
#
#      Is delivering now Switch to order menu  Price range  Aggregate rating  \
# 0                   No                   No            3               4.8
# ...

# %%
restaurant_dataset.describe()
# Out:
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# 25%              250.000000     1.000000          2.500000      5.000000
# 50%              400.000000     2.000000          3.200000     31.000000
# 75%              700.000000     2.000000          3.700000    131.000000
# max           800000.000000     4.000000          4.900000  10934.000000

# %%
restaurant_dataset.isnull().sum()
# Out:
# Average Cost for two    0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
restaurant_dataset.duplicated().sum()
# Out:
# 2871

# %%
restaurant_dataset.dropna(inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
restaurant_dataset['Price range'].value_counts().plot(kind='pie', autopct=lambda p: '{:.2f}%'.format(p), colors=['darkred', 'darkgreen', 'darkblue', 'darkorange'], textprops={'color': 'white'})

plt.title('Price Range Distribution (Dark Colors)')
# Out:
# Text(0.5, 1.0, 'Price Range Distribution (Dark Colors)')

# %%
restaurant_dataset['Aggregate rating'].value_counts().plot(kind='pie', autopct='%.2f', colormap='viridis')

plt.title('Aggregate Rating Distribution (Dark Rainbow Colors)')
# Out:
# Text(0.5, 1.0, 'Aggregate Rating Distribution (Dark Rainbow Colors)')

# %%
sns.distplot(restaurant_dataset['Aggregate rating'], color='darkblue', kde_kws={'color': 'darkred'})
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Density'>

# %%
sns.distplot(restaurant_dataset['Price range'], color='darkgreen', kde_kws={'color': 'darkblue'})
plt.title('Distribution of Price Ranges')
# Out:
# Text(0.5, 1.0, 'Distribution of Price Ranges')

# %%
sns.barplot(x=restaurant_dataset["Rating text"],y=restaurant_dataset["Votes"],hue =restaurant_dataset["Rating color"])
plt.title('Votes by Rating Text and Color (Dark Colors)')
plt.xlabel('Rating Text')
plt.ylabel('Votes')
# Out:
# Text(0, 0.5, 'Votes')

# %%
sns.scatterplot(x=restaurant_dataset["Aggregate rating"],y=restaurant_dataset["Votes"],hue=restaurant_dataset["Price range"])
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Votes'>

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

restaurant_dataset['Has Table booking'] = label_encoder.fit_transform(restaurant_dataset['Has Table booking'])
restaurant_dataset['Has Online delivery'] = label_encoder.fit_transform(restaurant_dataset['Has Online delivery'])
restaurant_dataset['Is delivering now'] = label_encoder.fit_transform(restaurant_dataset['Is delivering now'])
restaurant_dataset['Switch to order menu'] = label_encoder.fit_transform(restaurant_dataset['Switch to order menu'])
restaurant_dataset['Rating color'] = label_encoder.fit_transform(restaurant_dataset['Rating color'])
restaurant_dataset['Rating text'] = label_encoder.fit_transform(restaurant_dataset['Rating text'])
restaurant_dataset
# Out:
#       Average Cost for two  Has Table booking  Has Online delivery  \
# 0                     1100                  1                    0
# 1                     1200                  1                    0
# 2                     4000                  1                    0
# 3                     1500                  0                    0
# 4                     1500                  1                    0
# ...                    ...                ...                  ...
# 9546                    80                  0                    0
# 9547                   105                  0                    0
# 9548                   170                  0                    0
# 9549                   120                  0                    0
# 9550                    55                  0                    0
#
#       Is delivering now  Switch to order menu  Price range  Aggregate rating  \
# 0                     0                     0            3               4.8
# ...

# %%
correlation_matrix = restaurant_dataset.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', fmt=".2f", linewidths=0.5)

plt.title('Correlation Heatmap')
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import r2_score

# %%
x = restaurant_dataset.drop('Aggregate rating', axis=1)
y = restaurant_dataset['Aggregate rating']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.1,random_state=353)
x_train.head()
y_train.head()
# Out:
# 8696    0.0
# 1164    4.0
# 4824    3.2
# 7574    3.2
# 2961    2.3
# Name: Aggregate rating, dtype: float64

# %%
reg=LinearRegression()
reg.fit(x_train,y_train)
y_pred=reg.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.4484641996519262

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
reg = LinearRegression()
reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error (MSE): {mse:.2f}")
r2 = r2_score(y_test, y_pred)
print(f"R-squared (R2) Error: {r2:.2f}")
# Out:
# Mean Squared Error (MSE): 1.36
# R-squared (R2) Error: 0.45

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import numpy as np
import pandas as pd

data = {'Feature1': np.random.rand(100), 'Feature2': np.random.rand(100), 'Target': np.random.rand(100)}
restaurant_dataset = pd.DataFrame(data)

x = restaurant_dataset[['Feature1', 'Feature2']]
y = restaurant_dataset['Target']

def train_and_evaluate_decision_tree(x, y, test_size=0.1, random_state=105, min_samples_leaf=0.0001):

    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=test_size, random_state=random_state)

    DTree = DecisionTreeRegressor(min_samples_leaf=min_samples_leaf)
    DTree.fit(x_train, y_train)

    y_predict = DTree.predict(x_test)

    r2 = r2_score(y_test, y_predict)
    print("R-squared score:", r2)

train_and_evaluate_decision_tree(x, y)
# Out:
# R-squared score: -2.3053227817697155

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

DTree = DecisionTreeRegressor(min_samples_leaf=0.0001)

DTree.fit(x_train, y_train)

y_predict = DTree.predict(x_test)

mse = mean_squared_error(y_test, y_predict)
print(f"Mean Squared Error (MSE): {mse:.2f}")

r2 = r2_score(y_test, y_predict)
print(f"R-squared (R2) Error: {r2:.2f}")
# Out:
# Mean Squared Error (MSE): 0.06
# R-squared (R2) Error: 0.98

# %%
#MSE of 0.05 indicates that model's predictions are very accurate & low errors
#R2 value of 0.98 suggests that model is highly effective at explaining & predicting the target variable
#Decision Tree Regressor model is performing exceptionally well on your test data.
